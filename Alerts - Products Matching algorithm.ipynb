# %%
import pandas as pd
import numpy as np
import re
import string

# %%
# this is an implementation to match a product (entered in free text by the user) with a list of actual products

# %%
alertfr = pd.read_csv('alertsfr.csv', sep=';',encoding='utf-8')
productfr = pd.read_csv('productsfr.csv',sep=';',encoding="latin-1")

# %%
alertfr
# Out:
#                                               product
# 0             IPAD MINI 4 32 GO WIFI + 4g Or Débloqué
# 1      EXPRESSO À CAPSULES Dolce Gusto Krups Yy1786fd
# 2   ACER SWIFT Sf314-51-39zj 14 Core I3-6006u 2 Gh...
# 3                            IPAD 4 128 GO WIFI NOIR
# 4                COMPTEUR DE FANS Facebook 5 Chiffres
# 5           ASUS ZENFONE 2 SELFIE 32 Go Bleu Débloqué
# 6                        DORO 8031 8 GO NOIR Débloqué
# 7                         VENTILATEUR DYSON Cool Am07
# 8                           LG G6 32 GO NOIR Débloqué
# 9                 IPAD MINI 4 7,9'' 32 GO Wifi Argent
# 10            ROBOT PÂTISSIER Kitchenaid 5ksm150psecr
# 11             ECOUTEURS SAMSUNG Gear Iconx 4 Go Noir
# 12     EXPRESSO À CAPSULES Dolce Gusto Krups Yy1786fd
# 13               GALAXY A5 (2017) 32 GO Noir Débloqué
# 14                                  XPERIA ZX PREMIUM
# 15                                          iPhone 6s
# 16         ROBOT MULTIFONCTIONS Russell Hobbs Rh19006
# 17                                            Iphone7
# 18                         ASUS NEXUS 7 7 32 GO  Noir
# 19                             MacBook Pro Retina 154

# %%
productfr.head()
# Out:
#                                              product  \
# 0   ADVANCE PC Tour 19 CORE-I3-4160 3,6 GHz  - HD...
# 1   ALIENWARE 18 17,3 Intel Core i7 2,4 GHz GHz  ...
# 2   ALIENWARE 18-7312 18,4 Core i7 2,7 GHz  - SSD...
# 3   ARCHOS 101 Cesium 10,1 Atom Z3735F 1,33 GHz  ...
# 4   ARCHOS 140 Cesium 14 Atom Z3735F 1,33 GHz  - ...
#
#                                          description
# 0  ADVANCE core I5 + Ecran SYNCMASTER SA450 SAMSU...
# 1   Avec cet Alienware 18, régnez en maître sur v...
# 2  <div><strong><br>Ordinateur portable ALIENWARE...
# 3  <div><br></div><div><br></div><h3><strong>ARCH...
# 4  <div><br></div><h3><strong>ARCHOS 140 Cesium 1...

# %%
# create a set of punctuations and regex to use later
exclude = set(string.punctuation)
regex = re.compile('[%s]' % re.escape(string.punctuation))

# %%
def stripp(x, regex):
    r = x.lower()
    r = re.sub('\s+',' ',re.sub(regex,'',re.sub('<\w+>|</\w+>',' ',r)).strip(' '))
    r = re.sub('é','e', r)
    r = re.sub('è','e', r)
    r = re.sub('à', 'a', r)
    if re.match('((\w+)(\d))',r):
        r = re.search('((\w+)(\d))',r).group(2)+' '+re.search('((\w+)(\d))',r).group(3)
    r = r.split(' ')
    r = [i for i in r if i not in exclude]
    r = ' '.join(r)
    return r

# %%
# clean text for productfr dataset
productfr['clean_product'] = productfr['product'].apply(lambda x: stripp(x, regex))

# %%
productfr['clean_product'].head()
# Out:
# 0    advance pc tour 19 corei34160 36 ghz hdd 500 g...
# 1    alienware 18 173 intel core i7 24 ghz ghz ssd ...
# 2    alienware 187312 184 core i7 27 ghz ssd 64 go ...
# 3    archos 101 cesium 101 atom z3735f 133 ghz ssd ...
# 4    archos 140 cesium 14 atom z3735f 133 ghz ssd 3...
# Name: clean_product, dtype: object

# %%
# clean text for alertfr dataset
alertfr['clean_product'] = alertfr['product'].apply(lambda x: stripp(x, regex))

# %%
alertfr['clean_product']
# Out:
# 0                 ipad mini 4 32 go wifi 4g or debloque
# 1        expresso a capsules dolce gusto krups yy1786fd
# 2     acer swift sf3145139zj 14 core i36006u 2 ghz s...
# 3                               ipad 4 128 go wifi noir
# 4                  compteur de fans facebook 5 chiffres
# 5             asus zenfone 2 selfie 32 go bleu debloque
# 6                          doro 8031 8 go noir debloque
# 7                           ventilateur dyson cool am07
# 8                             lg g6 32 go noir debloque
# 9                      ipad mini 4 79 32 go wifi argent
# 10              robot pâtissier kitchenaid 5ksm150psecr
# 11               ecouteurs samsung gear iconx 4 go noir
# 12       expresso a capsules dolce gusto krups yy1786fd
# 13                   galaxy a5 2017 32 go noir debloque
# 14                                    xperia zx premium
# 15                                            iphone 6s
# 16           robot multifonctions russell hobbs rh19006
# 17                                             iphone 7
# 18                            asus nexus 7 7 32 go noir
# 19                               macbook pro retina 154
# Name: clean_product, dtype: object

# %%
# create a function that looks up intersection. this could have been done using set.intersection(), however, 
# we can notice that there are gramar mistakes. this function deals with simple grammar mistakes that concern mostly a reference
# one example is the Sony Experia XZ, the alert had ZX and the product had XZ
def intersect(alert,product):
    inter = set()
    for i in alert:
        if i in product:
            inter.add(i)
        elif i[::-1] in product:
            inter.add(i[::-1])
    return inter

# %%
# create a function that calculate the proportion of similarity between an alert and a product
def sim(alert, df_product):
    t2 = df_product.apply(lambda x: set(x.split(' ')))
    prop = t2.apply(lambda x: len(intersect(alert,x))/(len(alert)+len(x))).sort_values(ascending=False)
    ind_top_7 = prop[:7].index
    return ind_top_7

# %% [markdown]
# #### Test all alerts

# %%
for row in alertfr.itertuples():
    t1 = set(row[2].split(' '))
    inx = sim(t1, productfr['clean_product'])
    print('-------------------------- \n')
    print(row[1])
    print(productfr['product'].loc[inx])
    print('\n-------------------------- \n')
# Out:
# --------------------------
#
# IPAD MINI 4 32 GO WIFI + 4g Or Débloqué
# 12586            IPAD MINI 4 32 GO WIFI + 4g Or - Débloqué
# 20610        iPad mini 4 16 Go - Wifi + 4G - Or - Débloqué
# 20617        iPad mini 4 64 Go - Wifi + 4G - Or - Débloqué
# 20604       iPad mini 4 128 Go - Wifi + 4G - Or - Débloqué
# 20599    iPad mini 4 - 7,9'' 32 Go - Wifi + 4G - Argent...
# 20614    iPad mini 4 32 Go - Wifi + 4G - Gris sidéral -...
# 20601                iPad mini 4 - 7,9'' 32 Go - Wifi - Or
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# EXPRESSO À CAPSULES Dolce Gusto Krups Yy1786fd
# 9725       Expresso à capsules Dolce Gusto Krups YY1786FD
# 9722       Expresso à capsules Dolce Gusto Krups KP100BIB
# 9723       Expresso à capsules Dolce Gusto Krups KP1105ES
# 9720       Expresso à capsules Dolce Gusto KRUPS YY1500FD
# 9721    Expresso à capsules Dolce Gusto Krups KP1008 Y...
# 9724    Expresso à capsules Dolce Gusto Krups KP110H Oblo
# 9717         Expresso à capsule Dolce Gusto Krups movenza
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# ACER SWIFT Sf314-51-39zj 14 Core I3-6006u 2 Ghz  Ssd 128 Go Ram 4 Go
# 1168    Acer Swift SF314-51-39ZJ 14 Core i3-6006U 2 GH...
# 1154    Acer Swift 3 SF314-51-302G 14 Core i3 2 GHz  -...
# 1156    Acer Swift 3 SF314-51-34C3 14 Core I3-6006U 2 ...
# 1161    Acer Swift 3 SF314-51-57HZ 14 Core i5-6200U 2....
# 1157    Acer Swift 3 SF314-51-39GY 14 Core i3-6006U 2 ...
# 1155    Acer Swift 3 SF314-51-31VT 14 Core i3-6100U 2,...
# 1167    Acer Swift SF314-51-35NW 14 Core i3-6006U 2 GH...
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# IPAD 4 128 GO WIFI NOIR
# 20438              iPad 4 128 Go - Wifi - Noir
# 20437             iPad 4 128 Go - Wifi - Blanc
# 20450               iPad 4 32 Go - Wifi - Noir
# 20458               iPad 4 64 Go - Wifi - Noir
# 20436     iPad 4 128 Go - 4G - Noir - Débloqué
# 20433         iPad 4 - 9,7 16 Go - Wifi - Noir
# 20445    iPad 4 16 Go - Wifi - Noir - Bouygues
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# COMPTEUR DE FANS Facebook 5 Chiffres
# 3979                  Compteur de fans facebook 5 chiffres
# 3340           Caméra de sport LENCO SPORTCAM-600 - 5 Mpix
# 16324       Piano de cuisson 5 foyers BERTAZZONI AM85C21DX
# 19529    Table de cuisson - Gaz 5 foyers - DE DIETRICH ...
# 19535        Table de cuisson - Gaz 5 foyers - SMEG SR275X
# 19575    Table de cuisson - Induction 5 foyers - SMEG S...
# 19574    Table de cuisson - Induction 5 foyers - SIEMEN...
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# ASUS ZENFONE 2 SELFIE 32 Go Bleu Débloqué
# 2756     Asus ZenFone 2 Selfie 32 Go - Bleu - Débloqué
# 2757     Asus ZenFone 2 Selfie 32 Go - Noir - Débloqué
# 2755    Asus ZenFone 2 Selfie 32 Go - Blanc - Débloqué
# 2750     Asus ZenFone 2 Deluxe 32 Go - Noir - Débloqué
# 2752    Asus ZenFone 2 Deluxe 32 Go - Rouge - Débloqué
# 2754     Asus ZenFone 2 Laser 32 Go - Rouge - Débloqué
# 2751       Asus ZenFone 2 Deluxe 32 Go - Or - Débloqué
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# DORO 8031 8 GO NOIR Débloqué
# 9132          Doro 8031 8 Go - Noir - Débloqué
# 9131          Doro 8030 8 Go - Noir - Débloqué
# 20100    Wiko Darknight 8 Go - Noir - Débloqué
# 15899       Nokia E6-00 8 Go - Noir - Débloqué
# 20189        Wiko Sunny 8 Go - Noir - Débloqué
# 20637        iPhone 3GS 8 Go - Noir - Débloqué
# 3051      Blackberry Z3 8 Go - Noir - Débloqué
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# VENTILATEUR DYSON Cool Am07
# 19989                          Ventilateur DYSON COOL AM07
# 19988                               Ventilateur DYSON AM07
# 16451        Purificateur d'air DYSON pure cool link Tower
# 16452    Purificateur d'air connecté DYSON Cool Purifie...
# 19991                         Ventilateur ROWENTA VU6620F0
# 19990                       Ventilateur Honeywell HS-216E1
# 19987                              Ventilateur CAMRY 00055
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# LG G6 32 GO NOIR Débloqué
# 12990      LG G6 32 Go - Noir - Débloqué
# 12991      LG G6 64 Go - Noir - Débloqué
# 12988    LG G6 32 Go - Argent - Débloqué
# 13045     LG V10 32 Go - Noir - Débloqué
# 12971      LG G4 32 Go - Noir - Débloqué
# 12950      LG G2 32 Go - Noir - Débloqué
# 12960     LG G3 32 Go - Noir - Débloqué
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# IPAD MINI 4 7,9'' 32 GO Wifi Argent
# 20600            iPad mini 4 - 7,9'' 32 Go - Wifi - Argent
# 20599    iPad mini 4 - 7,9'' 32 Go - Wifi + 4G - Argent...
# 20601                iPad mini 4 - 7,9'' 32 Go - Wifi - Or
# 20597                      iPad mini 32 Go - Wifi - Argent
# 20620        iPad mini 4 7,9'' 32 Go - Wifi - Gris sidéral
# 20550                 iPad Pro 9,7'' 32 Go - Wifi - Argent
# 20469                 iPad Air - 9,7 32 Go - Wifi - Argent
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# ROBOT PÂTISSIER Kitchenaid 5ksm150psecr
# 16741              Robot pâtissier KitchenAid 5KSM150PSECR
# 16742              Robot pâtissier KitchenAid 5KSM150PSETG
# 16734              Robot pâtissier KITCHENAID 5KSM175PSEBY
# 16735     Robot pâtissier KITCHENAID 5KSM7580XEMS - Argent
# 16744    Robot pâtissier KitchenAid Artisan 5KSM125EOB ...
# 16743    Robot pâtissier KitchenAid 5KSM156 EFP - Blanc...
# 16726                       Robot pâtissier BOSCH MUM58K20
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# ECOUTEURS SAMSUNG Gear Iconx 4 Go Noir
# 9227        Ecouteurs Samsung Gear IconX 4 Go - Noir
# 18154               Samsung Wave 3 4 Go - Noir - SFR
# 17603     Samsung Galaxy Fame 4 Go - Noir - Débloqué
# 17626       Samsung Galaxy J1 4 Go - Noir - Débloqué
# 18153            Samsung Wave 3 4 Go - Noir - Orange
# 18000    Samsung Galaxy Tab 4 - 10.1 16 Go -  - Noir
# 17567    Samsung Galaxy Ace 2 4 Go - Noir - Débloqué
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# EXPRESSO À CAPSULES Dolce Gusto Krups Yy1786fd
# 9725       Expresso à capsules Dolce Gusto Krups YY1786FD
# 9722       Expresso à capsules Dolce Gusto Krups KP100BIB
# 9723       Expresso à capsules Dolce Gusto Krups KP1105ES
# 9720       Expresso à capsules Dolce Gusto KRUPS YY1500FD
# 9721    Expresso à capsules Dolce Gusto Krups KP1008 Y...
# 9724    Expresso à capsules Dolce Gusto Krups KP110H Oblo
# 9717         Expresso à capsule Dolce Gusto Krups movenza
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# GALAXY A5 (2017) 32 GO Noir Débloqué
# 17551     Samsung Galaxy A5 (2017) 32 Go - Noir - Débloqué
# 17549    Samsung Galaxy A5 (2017) - 32 Go - Noir - Débl...
# 17553     Samsung Galaxy A5 (2017) 32 Go - Rose - Débloqué
# 17552       Samsung Galaxy A5 (2017) 32 Go - Or - Débloqué
# 17550     Samsung Galaxy A5 (2017) 32 Go - Bleu - Débloqué
# 17589         Samsung Galaxy Alpha 32 Go - Noir - Débloqué
# 17935            Samsung Galaxy S7 32 Go - Noir - Débloqué
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# XPERIA ZX PREMIUM
# 18906    Sony Xperia XZ Premium DS 64 Go - Noir - Débloqué
# 18902             Sony Xperia XZ 32 Go - Argent - Débloqué
# 18903               Sony Xperia XZ 32 Go - Bleu - Débloqué
# 18904                Sony Xperia XZ 32 Go - Noir - Déloqué
# 18905               Sony Xperia XZ 32 Go - Rose - Débloqué
# 18989     Sony Xperia Z5 Premium 32 Go - Argent - Débloqué
# 18990       Sony Xperia Z5 Premium 32 Go - Noir - Débloqué
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# iPhone 6s
# 20818        iPhone 6S 128 Go - Or - Débloqué
# 20824     iPhone 6S 32 Go - Argent - Débloqué
# 20831         iPhone 6S 64 Go - Or - Débloqué
# 20816    iPhone 6S 128 Go - Argent - Débloqué
# 20828     iPhone 6S 64 Go - Argent - Débloqué
# 20826         iPhone 6S 32 Go - Or - Débloqué
# 20829       iPhone 6S 64 Go - Argent - Orange
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# ROBOT MULTIFONCTIONS Russell Hobbs Rh19006
# 16712           Robot multifonctions Russell Hobbs RH19006
# 16870        Russell Hobbs - 18560 - Robot Multifonctions
# 16884    Russell Hobbs - 20240 - Robot multifonctions I...
# 16913    Russell hobbs - 20350 - Robot Multifonctions D...
# 16877    Russell Hobbs - 19003 - Robot multifonctions C...
# 16868    Russell Hobbs - 18557 - Robot multifonctions s...
# 16693    Robot multifonctions - Russell Hobbs - 18511 -...
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# Iphone7
# 20851    iPhone 7 128 Go - Argent - Débloqué
# 4095       Coque iphone 7 Smart Battery Case
# 20869         iPhone 7 32 Go - Or - Débloqué
# 20865       iPhone 7 32 Go - Argent - Orange
# 20864     iPhone 7 32 Go - Argent - Débloqué
# 20863       iPhone 7 256 Go Rouge - Débloqué
# 20862     iPhone 7 256 Go - Rouge - Débloqué
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# ASUS NEXUS 7 7 32 GO  Noir
# 2158                     Asus Nexus 7 - 7 32 Go -  - Noir
# 2157                     Asus Nexus 7 - 7 32 Go -  - Noir
# 2156                Asus Nexus 7 - 7 16  Go - Wifi - Noir
# 1889    Asus Asus Google Nexus 7 32Go 2ème Génération ...
# 2775                      Asus ZenPad - 7 16 Go -  - Noir
# 1874             Asus 90NP01Z1-M00510 - 7 16 Go -  - Noir
# 2820              Asus Zenfone Go 32 Go - Noir - Débloqué
# Name: product, dtype: object
#
# --------------------------
#
# --------------------------
#
# MacBook Pro Retina 154
# 15008    MacBook Pro Retina 13 Core i7 3 GHz  - SSD 256...
# 15009    MacBook Pro retina 13 Core i5 2 GHz  - SSD 256...
# 19726                                      Tomtom PRO 7100
# 14743    MacBook Pro 13 Core 2 duo 2 GHz  - HDD 160 Go ...
# 14834    MacBook Pro 13 Core i5 2.9 GHz  - SSD 512 Go -...
# 14845    MacBook Pro 13 Core i7 2.7 GHz  - HDD 750 Go -...
# 14844    MacBook Pro 13 Core i7 2.7 GHz  - HDD 500 Go -...
# Name: product, dtype: object
#
# --------------------------

# %% [markdown]
# ### Suggested improvements:

# %% [markdown]
# - improve the misspelled words detection function
# - implement the model with other languages
# - find a common representation of different products for different languages
# - use the description of every product as a weight in case of equal proportion
# - use of ngrams and TD-IDF for refined lookup
